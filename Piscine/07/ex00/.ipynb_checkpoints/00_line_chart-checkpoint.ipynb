# %% [markdown]
# ## create a connection to the database using the library sqlite3

# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('data/checking-logs.sqlite.sqlite copy')
pd.io.sql.read_sql('select * from pageviews', conn)
# Out:
#       index      uid                    datetime
# 0         0  admin_1  2020-04-17 12:01:08.463179
# 1         1  admin_1  2020-04-17 12:01:23.743946
# 2         2  admin_3  2020-04-17 12:17:39.287778
# 3         3  admin_3  2020-04-17 12:17:40.001768
# 4         4  admin_1  2020-04-17 12:27:30.646665
# ...     ...      ...                         ...
# 1075   1075  user_25  2020-05-21 23:23:49.995349
# 1076   1076  admin_1  2020-05-21 23:49:22.386789
# 1077   1077  admin_1  2020-05-22 10:36:14.662600
# 1078   1078   user_5  2020-05-22 11:30:18.368990
# 1079   1079  user_17  2020-05-22 18:22:22.847815
#
# [1080 rows x 3 columns]

# %% [markdown]
# ## run a query that gets the datetime from the pageviews table, selecting only the users and not the admins using Pandas &&& create a new dataframe where the visits are counted and grouped by date

# %%
visits = pd.io.sql.read_sql("""
SELECT strftime("%Y-%m-%d",datetime) AS datetime, COUNT(strftime("%Y-%m-%d",datetime)) AS views
    FROM pageviews
    WHERE uid LIKE "user_%"
    GROUP BY strftime("%Y-%m-%d",datetime)
""", conn)
visits
# Out:
#       datetime  views
# 0   2020-04-17      1
# 1   2020-04-18     23
# 2   2020-04-19     15
# 3   2020-04-21      3
# 4   2020-04-22      1
# 5   2020-04-23      5
# 6   2020-04-25      1
# 7   2020-04-26      8
# 8   2020-04-28      2
# 9   2020-04-29      4
# 10  2020-04-30      9
# 11  2020-05-01      3
# 12  2020-05-02      6
# 13  2020-05-03     19
# 14  2020-05-04      1
# 15  2020-05-05      1
# 16  2020-05-06      3
# 17  2020-05-07      2
# 18  2020-05-08     48
# 19  2020-05-09     19
# 20  2020-05-10    110
# 21  2020-05-11    200
# 22  2020-05-12     85
# 23  2020-05-13    102
# 24  2020-05-14    187
# 25  2020-05-15     29
# 26  2020-05-16      4
# 27  2020-05-17      9
# 28  2020-05-18     51
# 29  2020-05-19     11
# 30  2020-05-20     12
# 31  2020-05-21     11
# 32  2020-05-22      2

# %%
visits.plot(figsize=(15,8),  fontsize=8, x='datetime', rot=90)
# Out:
# <AxesSubplot:xlabel='datetime'>
